# %% [markdown]
# <a href="https://colab.research.google.com/github/Tayyab7404/Tayyab7404/blob/main/IPL%20Score%20Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IPL Score Prediction using Machine Learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn import preprocessing
import keras

# %% [markdown]
# ### Loading the dataset:

# %%
ipl = pd.read_csv('ipl_data.csv')

display(ipl)
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4      Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                      ...                          ...          ...
# 76009         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76010         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76011         Mumbai Indians       Rising Pune Supergiant    KH Pandya
# 76012         Mumbai Indians       Rising Pune Supergiant   MG Johnson
# 76013         Mumbai Indians       Rising Pune Supergiant    KH Pandya
#
#              bowler  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 0           P Kumar     1        0    0.1            1               0
# 1           P Kumar     1        0    0.2            1               0
# 2           P Kumar     2        0    0.2            2               0
# 3           P Kumar     2        0    0.3            2               0
# 4           P Kumar     2        0    0.4            2               0
# ...             ...   ...      ...    ...          ...             ...
# 76009  DT Christian   121        7   19.2           40               0
# 76010  DT Christian   127        7   19.3           46               0
# 76011  DT Christian   128        7   19.4           47               0
# 76012  DT Christian   129        7   19.5           48               0
# 76013  DT Christian   129        8   19.6           47               1
#
#        striker  non-striker  total
# 0            0            0    222
# 1            0            0    222
# 2            0            0    222
# 3            0            0    222
# 4            0            0    222
# ...        ...          ...    ...
# 76009       40           12    129
# 76010       46           12    129
# 76011       47           12    129
# 76012       47           13    129
# 76013       47           13    129
#
# [76014 rows x 15 columns]

# %% [markdown]
# ### Data Pre-processing:

# %%
# Dropping certain features

df = ipl.drop(['date', 'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5','mid', 'striker', 'non-striker'], axis =1)

display(df)

X = df.drop(['total'], axis =1)
y = df['total']
# Out:
#                                            venue               bat_team  \
# 0                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 1                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 2                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 3                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 4                          M Chinnaswamy Stadium  Kolkata Knight Riders
# ...                                          ...                    ...
# 76009  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76010  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76011  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76012  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76013  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
#                          bowl_team      batsman        bowler  total
# 0      Royal Challengers Bangalore   SC Ganguly       P Kumar    222
# 1      Royal Challengers Bangalore  BB McCullum       P Kumar    222
# 2      Royal Challengers Bangalore  BB McCullum       P Kumar    222
# 3      Royal Challengers Bangalore  BB McCullum       P Kumar    222
# 4      Royal Challengers Bangalore  BB McCullum       P Kumar    222
# ...                            ...          ...           ...    ...
# 76009       Rising Pune Supergiant    KH Pandya  DT Christian    129
# 76010       Rising Pune Supergiant    KH Pandya  DT Christian    129
# 76011       Rising Pune Supergiant    KH Pandya  DT Christian    129
# 76012       Rising Pune Supergiant   MG Johnson  DT Christian    129
# 76013       Rising Pune Supergiant    KH Pandya  DT Christian    129
#
# [76014 rows x 6 columns]

# %% [markdown]
# ### Label Encoding:

# %%
#Label Encoding

from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object for each categorical feature
venue_encoder = LabelEncoder()
batting_team_encoder = LabelEncoder()
bowling_team_encoder = LabelEncoder()
striker_encoder = LabelEncoder()
bowler_encoder = LabelEncoder()

# Fit and transform the categorical features with label encoding
X['venue'] = venue_encoder.fit_transform(X['venue'])
X['bat_team'] = batting_team_encoder.fit_transform(X['bat_team'])
X['bowl_team'] = bowling_team_encoder.fit_transform(X['bowl_team'])
X['batsman'] = striker_encoder.fit_transform(X['batsman'])
X['bowler'] = bowler_encoder.fit_transform(X['bowler'])

# %% [markdown]
# ### Train Test Split:

# %%
# Train test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Feature Scaling:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and testing data

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Define the Neural Network:

# %%
# Define the neural network model
model = keras.Sequential([
    keras.layers.Input( shape=(X_train_scaled.shape[1],)), # Input layer
    keras.layers.Dense(512, activation='relu'), # Hidden layer with 512 units and ReLU activation
    keras.layers.Dense(216, activation='relu'), # Hidden layer with 216 units and ReLU activation
    keras.layers.Dense(1, activation='linear') # Output layer with linear activation for regression
])

# Compile the model with Huber loss
huber_loss = tf.keras.losses.Huber(delta=1.0) # You can adjust the 'delta' parameter as needed
model.compile(optimizer='adam', loss=huber_loss) # Use Huber loss for regression

# %% [markdown]
# ### Model Training:

# %%
# Train the model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=64, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/50
# 832/832 [==============================] - 6s 6ms/step - loss: 31.8183 - val_loss: 22.2693
# Epoch 2/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.4114 - val_loss: 22.2319
# Epoch 3/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.2877 - val_loss: 22.2516
# Epoch 4/50
# 832/832 [==============================] - 4s 5ms/step - loss: 22.2727 - val_loss: 21.9029
# Epoch 5/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.2083 - val_loss: 21.8809
# Epoch 6/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.2149 - val_loss: 21.8885
# Epoch 7/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.1535 - val_loss: 21.8534
# Epoch 8/50
# 832/832 [==============================] - 6s 8ms/step - loss: 22.1124 - val_loss: 21.8761
# Epoch 9/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.1327 - val_loss: 22.6878
# Epoch 10/50
# 832/832 [==============================] - 4s 5ms/step - loss: 22.1557 - val_loss: 21.7905
# Epoch 11/50
# 832/832 [==============================] - 6s 7ms/step - loss: 22.0967 - val_loss: 21.7582
# Epoch 12/50
# 832/832 [==============================] - 4s 5ms/step - loss: 22.0783 - val_loss: 21.7677
# Epoch 13/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.0662 - val_loss: 21.8670
# Epoch 14/50
# 832/832 [==============================] - 6s 7ms/step - loss: 22.0876 - val_loss: 21.7279
# Epoch 15/50
# 832/832 [==============================] - 4s 5ms/step - loss: 22.0719 - val_loss: 22.0276
# Epoch 16/50
# 832/832 [==============================] - 5s 6ms/step - loss: 22.0581 - val_loss: 21.7807
# Epoch 17/50
# 832/832 [==============================] - 6s 7ms/step - loss: 22.0400 - val_loss: 22.0519
# Epoch 18/50
# 832/832 [==============================] - 4s 5ms/step - loss: 22.0166 - val_loss: 21.7830
# Epoch 19/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.9478 - val_loss: 21.6664
# Epoch 20/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.8378 - val_loss: 21.8137
# Epoch 21/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.7674 - val_loss: 21.4184
# Epoch 22/50
# 832/832 [==============================] - 6s 7ms/step - loss: 21.6952 - val_loss: 21.5529
# Epoch 23/50
# 832/832 [==============================] - 4s 5ms/step - loss: 21.6429 - val_loss: 21.6377
# Epoch 24/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.6325 - val_loss: 21.4123
# Epoch 25/50
# 832/832 [==============================] - 6s 8ms/step - loss: 21.5069 - val_loss: 21.2343
# Epoch 26/50
# 832/832 [==============================] - 4s 5ms/step - loss: 21.4903 - val_loss: 22.0012
# Epoch 27/50
# 832/832 [==============================] - 4s 5ms/step - loss: 21.4361 - val_loss: 21.1507
# Epoch 28/50
# 832/832 [==============================] - 6s 7ms/step - loss: 21.3636 - val_loss: 21.0416
# Epoch 29/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.2378 - val_loss: 20.9564
# Epoch 30/50
# 832/832 [==============================] - 5s 6ms/step - loss: 21.2153 - val_loss: 20.8939
# Epoch 31/50
# 832/832 [==============================] - 6s 7ms/step - loss: 21.0897 - val_loss: 20.8514
# Epoch 32/50
# 832/832 [==============================] - 4s 5ms/step - loss: 21.0504 - val_loss: 20.7505
# Epoch 33/50
# 832/832 [==============================] - 5s 6ms/step - loss: 20.9751 - val_loss: 20.7730
# Epoch 34/50
# 832/832 [==============================] - 5s 6ms/step - loss: 20.8851 - val_loss: 20.7982
# Epoch 35/50
# 832/832 [==============================] - 4s 5ms/step - loss: 20.8619 - val_loss: 20.5609
# Epoch 36/50
# 832/832 [==============================] - 5s 6ms/step - loss: 20.7116 - val_loss: 20.4843
# Epoch 37/50
# 832/832 [==============================] - 5s 6ms/step - loss: 20.6336 - val_loss: 20.2637
# Epoch 38/50
# 832/832 [==============================] - 4s 5ms/step - loss: 20.4767 - val_loss: 20.1616
# Epoch 39/50
# 832/832 [==============================] - 5s 6ms/step - loss: 20.3420 - val_loss: 20.2529
# Epoch 40/50
# 832/832 [==============================] - 6s 7ms/step - loss: 20.1453 - val_loss: 20.1342
# Epoch 41/50
# 832/832 [==============================] - 4s 5ms/step - loss: 20.0135 - val_loss: 19.7188
# Epoch 42/50
# 832/832 [==============================] - 5s 6ms/step - loss: 19.8678 - val_loss: 19.4915
# Epoch 43/50
# 832/832 [==============================] - 6s 7ms/step - loss: 19.7536 - val_loss: 19.5175
# Epoch 44/50
# 832/832 [==============================] - 5s 6ms/step - loss: 19.6005 - val_loss: 19.4197
# Epoch 45/50
# 832/832 [==============================] - 6s 7ms/step - loss: 19.5208 - val_loss: 19.2158
# Epoch 46/50
# 832/832 [==============================] - 5s 6ms/step - loss: 19.3927 - val_loss: 19.3238
# Epoch 47/50
# 832/832 [==============================] - 5s 6ms/step - loss: 19.3320 - val_loss: 19.2756
# Epoch 48/50
# 832/832 [==============================] - 7s 8ms/step - loss: 19.1990 - val_loss: 19.0138
# Epoch 49/50
# 832/832 [==============================] - 4s 5ms/step - loss: 19.1537 - val_loss: 18.9768
# Epoch 50/50
# 832/832 [==============================] - 4s 5ms/step - loss: 19.0442 - val_loss: 19.2777

# %%
model_losses = pd.DataFrame(model.history.history)
model_losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Model Evaluation:

# %%
# Make predictions
predictions = model.predict(X_test_scaled)

from sklearn.metrics import mean_absolute_error,mean_squared_error
mean_absolute_error(y_test,predictions)
# Out:
# 713/713 [==============================] - 2s 2ms/step
# 19.770487932917373

# %% [markdown]
# ### Let’s create an Interactive Widget:

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

import warnings
warnings.filterwarnings("ignore")

venue = widgets.Dropdown(options=df['venue'].unique().tolist(),description='Select Venue:')
batting_team = widgets.Dropdown(options =df['bat_team'].unique().tolist(), description='Select Batting Team:')
bowling_team = widgets.Dropdown(options=df['bowl_team'].unique().tolist(), description='Select Bowling Team:')
striker = widgets.Dropdown(options=df['batsman'].unique().tolist(), description='Select Striker:')
bowler = widgets.Dropdown(options=df['bowler'].unique().tolist(), description='Select Bowler:')

predict_button = widgets.Button(description="Predict Score")

def predict_score(b):
    with output:
        clear_output() # Clear the previous output

        # Decode the encoded values back to their original values
        decoded_venue = venue_encoder.transform([venue.value])
        decoded_batting_team = batting_team_encoder.transform([batting_team.value])
        decoded_bowling_team = bowling_team_encoder.transform([bowling_team.value])
        decoded_striker = striker_encoder.transform([striker.value])
        decoded_bowler = bowler_encoder.transform([bowler.value])

        input = np.array([decoded_venue, decoded_batting_team, decoded_bowling_team,decoded_striker, decoded_bowler])
        input = input.reshape(1,5)
        input = scaler.transform(input)
        #print(input)
        predicted_score = model.predict(input)
        predicted_score = int(predicted_score[0,0])

        print(predicted_score)

# %% [markdown]
# ### Score Predictor:

# %%
predict_button.on_click(predict_score)
output = widgets.Output()
display(venue, batting_team, bowling_team, striker, bowler, predict_button, output)
# Out:
# Dropdown(description='Select Venue:', options=('M Chinnaswamy Stadium', 'Punjab Cricket Association Stadium, M…
# Dropdown(description='Select Batting Team:', options=('Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasth…
# Dropdown(description='Select Bowling Team:', options=('Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi…
# Dropdown(description='Select Striker:', options=('SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey', 'Moha…
# Dropdown(description='Select Bowler:', options=('P Kumar', 'Z Khan', 'AA Noffke', 'JH Kallis', 'SB Joshi', 'CL…
# Button(description='Predict Score', style=ButtonStyle())
# Output()
